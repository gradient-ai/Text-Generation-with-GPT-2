# %% [markdown]
# ### GPT-2
# GPT-2 is a large transformer-based language model with 1.5 billion parameters, trained on a dataset[1]
# We created a new dataset which emphasizes diversity of content, by scraping content from the Internet. In order to preserve document quality, we used only pages which have been curated/filtered by humans—specifically, we used outbound links from Reddit which received at least 3 karma. This can be thought of as a heuristic indicator for whether other users found the link interesting (whether educational or funny), leading to higher data quality than other similar datasets, such as CommonCrawl.
#
#  of 8 million web pages. GPT-2 is trained with a simple objective: predict the next word, given all of the previous words within some text. The diversity of the dataset causes this simple goal to contain naturally occurring demonstrations of many tasks across diverse domains. GPT-2 is a direct scale-up of GPT, with more than 10X the parameters and trained on more than 10X the amount of data.
#
# GPT-2 displays a broad set of capabilities, including the ability to generate conditional synthetic text samples of unprecedented quality, where we prime the model with an input and have it generate a lengthy continuation. In addition, GPT-2 outperforms other language models trained on specific domains (like Wikipedia, news, or books) without needing to use these domain-specific training datasets. On language tasks like question answering, reading comprehension, summarization, and translation, GPT-2 begins to learn these tasks from the raw text, using no task-specific training data. While scores on these downstream tasks are far from state-of-the-art, they suggest that the tasks can benefit from unsupervised techniques, given sufficient (unlabeled) data and compute [https://openai.com/blog/better-language-models/]
#
# gpt2-simple by https://github.com/minimaxir/gpt-2-simple

# %%
# !pip3 install gpt-2-simple

# %%
import gpt_2_simple as gpt2
import tensorflow as tf
import pandas as pd
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## Downloading GPT-2
#
# If you're retraining a model on new text or just using GPT-2 to generate text, you need to download one of the GPT-2 model first.
#
# There are three released sizes of GPT-2:
#
# * `124M` (default): the "small" model, 500MB on disk.
# * `355M`: the "medium" model, 1.5GB on disk.
# * `774M`: the "large" model, make sure to put this one into /storage

# %%
#download gpt2
gpt2.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 605Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 4.22Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 517Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [01:03, 7.81Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 410Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 2.83Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 2.88Mit/s]

# %% [markdown]
# ## Generate Text From The Pretrained Model
#
# If you want to generate text from the pretrained model, not a finetuned model, pass `model_name` to `gpt2.load_gpt2()` and `gpt2.generate()`.

# %%
model_name = '124M'
sess = gpt2.start_tf_sess()

gpt2.load_gpt2(sess, model_name=model_name)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0215 12:29:47.874370 139957605082944 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Loading pretrained model models/124M/model.ckpt

# %% [markdown]
# #### optional-but-helpful parameters for `gpt2.generate`:
#
# You can also pass in a `prefix` to the generate function to force the text to start with a given character sequence and generate text from there (good if you add an indicator when the text starts).
#
# You can also generate multiple texts at a time by specifing `nsamples`. Unique to GPT-2, you can pass a `batch_size` to generate multiple samples in parallel, giving a massive speedup (in Colaboratory, set a maximum of 20 for `batch_size`).
#
# #### required parameters
# *  **`length`**: Number of tokens to generate (default 1023, the maximum)
# * **`temperature`**: The higher the temperature, the crazier the text (default 0.7, recommended to keep between 0.7 and 1.0)
# * **`top_k`**: Limits the generated guesses to the top *k* guesses (default 0 which disables the behavior; if the generated output is super crazy, you may want to set `top_k=40`)
# * **`top_p`**: Nucleus sampling: limits the generated guesses to a cumulative probability. (gets good results on a dataset with `top_p=0.9`)
# * **`truncate`**: Truncates the input text until a given sequence, excluding that sequence (e.g. if `truncate='<|endoftext|>'`, the returned text will include everything before the first `<|endoftext|>`). It may be useful to combine this with a smaller `length` if the input texts are short.
# *  **`include_prefix`**: If using `truncate` and `include_prefix=False`, the specified `prefix` will not be included in the returned text.

# %%
gpt2.generate(sess,
              model_name=model_name,
              prefix="Software demos are a form of creativity",
              length=100,
              temperature=0.7,
              top_p=0.9,
              nsamples=5,
              batch_size=5
              )
# Out:
# W0215 12:29:52.719801 139957605082944 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:32: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Software demos are a form of creativity and, while we have never heard of any games that use them, we do think it's good to have them.
#
# Kazuzawa: Speaking of games, do you think that the market is wide open to getting the best of both worlds?
#
# Fakazawa: We believe that it's the best possible thing. We've got a great range of games and we're always looking for new ways to make things and we're always looking for new ways to build on the
# ====================
# Software demos are a form of creativity that is not only possible, but also fun. We have seen some great examples of this in our own company, but we have a lot of work to do.
#
# We have a strong desire to make the game better, and we're committed to making it better. We've been working with the game development team to develop and test the game for a couple of weeks now. The team is in a very strong state of development and we are getting ready to release it to the public. We
# ====================
# Software demos are a form of creativity. If you have a demo of your own, it's likely you'll find it useful in the future.
#
# Do you have a demo of your own? Do you have a demo of your own, too? If you don't, try to create it yourself.
#
# Crowdfunding is a way for people to get in touch with each other. They can donate to your project, give to your project's local charities or even write to you with their suggestions for the next release.
# ====================
# Software demos are a form of creativity. This is why I decided to create a demo of my new plugin. I didn't want to build a demo that would only be used for the demo itself. It would be a way to share the results of my latest code with the community. I wanted to make it easier for people to find out what I was up to and to make it easier to contribute.
#
# I'm always looking for ways to make it better, so this project is going to use the following principles:
#
#
# ====================
# Software demos are a form of creativity, and they will always need to be made. They are often made for specific uses, or for a specific purpose, and need to be as creative as possible.
#
# The goal of the game is to make sure that every single level is a challenge. In order to accomplish this, you must be able to solve puzzles, collect items, and collect money. There are a few pieces of advice in the game that you can find helpful in the real world, such as:
#
# Make sure
# ====================

# %% [markdown]
# ## Finetune GPT-2
#
# Start by uploading a input.txt that you will be for tuning the model. This can be song lyrics, news articles, ect. We provided the tinyshakespeake dataset.

# %%
file_name = "input.txt"

# %% [markdown]
# #### Training the model
#
# The next cell will start the actual finetuning of GPT-2. It creates a persistent TensorFlow session which stores the training config, then runs the training for the specified number of `steps`. (to have the finetuning run indefinitely, set `steps = -1`)
#
# The model checkpoints will be saved in `/checkpoint/run1` by default. The checkpoints are saved every 500 steps (can be changed) and when the cell is stopped.
#
# Other optional-but-helpful parameters for `gpt2.finetune`:
#
#
# *  **`restore_from`**: Set to `fresh` to start training from the base GPT-2, or set to `latest` to restart training from an existing checkpoint.
# * **`sample_every`**: Number of steps to print example output
# * **`print_every`**: Number of steps to print training progress.
# * **`learning_rate`**:  Learning rate for the training. (default `1e-4`, can lower to `1e-5` if you have <1MB input data)
# *  **`run_name`**: subfolder within `checkpoint` to save the model. This is useful if you want to work with multiple models (will also need to specify  `run_name` when loading the model)
# * **`overwrite`**: Set to `True` if you want to continue finetuning an existing model (w/ `restore_from='latest'`) without creating duplicate copies.

# %%
tf.reset_default_graph()
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              dataset=file_name,
              model_name='124M',
              steps=50,
              restore_from='fresh',
              run_name='run_1',
              print_every=5,
              sample_every=2,
              save_every=10
              )
# Out:
# Loading checkpoint models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:02<00:00,  2.19s/it]
# dataset has 338025 tokens
# Training...
# ======== SAMPLE 1 ========
# ness in its capacity to create and serve a whole world. We can never have that if we just try to take things apart. And so you can't do anything about them either. You can't take anything apart. You can't be the center of the world, and then there's no way to make your world as useful as the center-piece of your world. We never have the power of the world. It's never the center of things, unless you have something more or less there. So I think we have to stop trying to make things as useful as our world, and to stop believing in our world. So, we need to start thinking about people who are actually making lives. So we need to start making people more powerful, kind of making people more useful. And that's just one way. But in my view of things and things that are useful, I think the way to do it is to take this whole thing apart into smaller pieces that are useful to me, because I just can't see the whole whole world as useless. I don't think that's the right way. I think you do have to take this piece off of your mind or your heart or your body and it's going to do nothing. That's just not going to work. People who have the ability to take the whole thing apart for a reason that makes it useful to them, for this reason, that makes them people, are going to have a problem. And so here, I think it's a real problem for ourselves, for the world, that I could never make it useful to me: Because I can't. Because I don't know how to do it. I'm not able to do it. Because I'm not happy with what the world has done to it.
#
# In my view, there is a real problem for us here, because you can only make things useful if you have people who will take them for what they are. And that is what I'm trying to do here: Take the whole thing apart for a reason that makes it useful so that you can make it useful that people not be miserable and think of you that way. And so that's what I'm trying to do.
#
# One thing that I believe in is that we are going to try people's ability to take things apart. And in the same way as I do in the past, what I believe people are going to struggle around is making things usable. I believe that's what I'd like people to accomplish. I think that's what I'd like it to be: Making things useful. And I think it is going to do that, and that's what's going to happen. That is what has happened and where is now. But we have to start thinking about people that are making their lives better and making them smarter and making them more powerful.
# And not just for those making their lives better. We also have to start thinking about people that are creating an enormous amount of new stuff. We're going to make things more useful to them — as I think we need to do — to give them a lot of new information that they need to use. And that's how we've got to start, and I would actually recommend a little bit of that to somebody when they're in their 20s to 20s.
# If you're interested:
# You're also interested in: A little bit of that, a little bit of the world.
# Thank you again for coming, but I appreciate that. I appreciate that.
# Thanks!
# Thanks!<|endoftext|>Ferguson officers had not had time to respond to calls that a white man with a black bodyguard pulled him over for running over a carjacking suspect last week.
#
# Manny Cusack was driving his own Hyundai through Westmead after he got an officer's call at his front door.
#
# He was in a hurry when when he got an officer's message he realized he would get a ticket and stop his car for a red light.
#
# He ignored it and left the intersection.
#
# An officer told Cusack: "Hey, you have a black suspect, who he pulled over because he got a ticket - I'm trying to stop him."
#
# Cusack was pulled over for a traffic light violation - after that the officer was called and his story was quickly covered up by the police.
#
# After Cusack's story began to circulate, The Guardian asked the police for a response on whether the officer's words, actions, and demeanor were a reflection of what they had witnessed.
#
# The police responded, in that they have "no record of it happening to you."
#
# As for the officers who were interviewed, they said this is not a public safety issue and they have "no idea where anyone else was at the event".
#
# They did ask the officer if Cusack has been the subject of a threat and if he was aware of the situation or thought there had been an altercation.
# The police also pointed to C
#
# ======== SAMPLE 1 ========
#  d, if the same character is placed at the end of the line. The cursor can not appear after a preceding character. A "
#
# " character is not used in this code because it is the only way to insert a character into it; the other characters may be placed after each other within a line.
#
# Here is an example. Imagine that the following are used in a line at the beginning of a line. The character (D) begins with the left-hand letter F. The next character (G) begins with the same character A. The final character, B, begins with the letter (B), the same way that the next character, B would be in line. (D)
# Now, in the following line, C receives first the next letter, D, when the right-hand-word character is already in line, but there is no other character to put it in the next line, because the current character A is at the end of the line. A "
# " character and B B are positioned before C, A, and G.
# The cursor line is not a line, but a line with a character in it. The character is positioned in a line at the end of the line.
#
# This code, in its very basic nature, is not well-suited for human usage. When that character is placed inside the line C, C must contain a character at the end of it. Thus C is placed before C. Therefore the cursor cannot be moved as well as C.
# We should thus say: C is at the end of the line C, C; C must have a new character (D), but the cursor must still move, not in any other way than within the line from the previous line to the line before C, D. Otherwise C must not have a new character, but the cursor must move, not in any other way than within the line before C, D; and C does not need a new line to move from C to D, but in any other way, which is its own kind of moving.
# Note, in the last line, D is just at the point the cursor reaches D. Notice again that a "
# " character is not placed at the end of the line D; this is the place where C enters C; C therefore must stay in the line D, and the cursor must move again to reach C, C and C, in order to continue in it.
#
# At this point, "
# " is at the end D of C; C must be moved to reach A, but in D, A!
# We may now take another view.
# In the last line, in C, C is at the end A of "
# "; in "
# " it is at D or C; A must remain in D, A!
# So now it can be shown that the following is the place where A, A! moves C; in D, D! D is at A! and B should remain in D!
# Finally, a D should be at A! at D! B!
# C should move D and C!
#
# That this is not a place where A moves C! It is certainly a place where C moves A ! C will stay in the line B, A! but D will not, B, D! not at A! D, A! !
#
# In any other case, this would require a line at which C moves A, and that line cannot be moved at A' as well; A will be at C, C (or C is at the end A, and B is at A') and A should not be moved at A!
# And we now say: A moves at C C is at A!!!!! and C moves D B.
#
# When that's done,
# C moves at D B .
# It then moves back from A at B! B! A moves at D! D! B moves at D! B, is at D! B! C! at B! and D moves at D! B! C! and D! B moves at D! B! to the end B.
# In such a case,
# B moves A ! moves B ! then,
# B moves J move J with J and
# I move P move P with P.
# And so to that, the following is the place where "A" moves A:
# C is at the end at C, B (or B) moves A, B moves B !
# Then C moves D B .
# Then A moves D a , B moves A moves B! and B moves C by D B .
# Then A moves C B .
#
# Then A moves D , B moves C and
# C moves B
#  by C B .
# C moves C A , B moves C B ! and C moves B B ! and the D moves B B !
# And for that,
# C moves D C moves C A B ! and C moves D C B
#
# [5 | 40.24] loss=3.65 avg=3.65
# ======== SAMPLE 1 ========
# All the same features from the other two games, this one is even more unique. It's basically all in your face, the art isn't all that good but it's all done in a very clever way.
#
# This is the first time ever that this series had three separate, completely different environments with an open-world atmosphere to choose from (I was also the only human in that room)
#
#
# The first three characters that do come from this run, we're told:
#
# One of the main characters is a female;
# two of the side characters are male and
# one of the main characters is a male.
# This time, if you're a fan of some of your early-game gaming favorites and you're trying out some stuff here this time around, it's only going to get a little more exciting as we get into the second half. I guess the problem with not being able to get into these games by yourself is that I'm in a position where there's this big, massive, unstructured universe in which I'm able to explore everything, I think all three of them; and then the fourth character, who's actually a little younger but I'd guess is also a little old (at least a little, I guess), has no more role in the world, and he's not in charge. Then the big problem is that they have this very small, absolutely bare-bones world. And by the time it starts to get to the top of the heap it could be three years away!
# I guess I should probably stick on doing this first thing, I'd just be writing a chapter on the games I love, or maybe do some of them, but I'd like to bring this here to your attention, so let me know in any kind of way your thoughts.
# So, you've got this first two games; you'll see some changes over time but I'll just say that I have a very great deal of love for all of the main series games which I did in my early days of gaming. I love the fact that they're all different but I really love the fact that they're all very well made and very well acted. Also, it's a shame the old series's only two main characters come out to play. The whole world that each character has a role to play is only so far removed from those other characters' characters; this is simply too much.
# So if you'll excuse me, I'll save you from this by looking at the first game which I think might have been my favourite of them all, the first, if you think that was pretty good.
# Anyway, as you're reading, here's some more news...
# I just finished doing this last game and I'm gonna do a thing (of the sort I'll go out of my way to do and make this stuff, and it's on my list, though I'll be taking some time to come and go on it).
# And I mean I'd love to pick up your favourite, so I'll do my little best to tell you something, so stay tuned, and if I do anything that I think should be fun or enlightening at the end of the day it's the games I'm most interested in but I'll go back to this one for some more news.
# I did get some bad news yesterday, it was reported that the studio was suing its own boss. I'd have to guess that's good news to have some kind of dispute here.
# So I must be back now - with a good deal of extra excitement and I'd be happy to see where this goes, not so much.
# Anyway, there's something to be said for having the 'most creative' team in the entire indie business - which I think is fair enough. But it is also fair from my point of view that the whole thing should be about the best of the 'other' games, of the original games and of the other.
# I can't help thinking that the whole project has been written up not just for The Last Man on Earth, but for some of the very best games out there now.
# For my next stop I'll end up getting into the latest development news on this series - and the very best gaming news which happens at the present time is this.
# I have got the 'next big development' planned for next month, a thing which is only likely to be a small part of the rest of this year's E3. And I'll be taking it to The Ritz, which I should be at if you've not been following this project, but it's all too little time that I don't want to do any more, and so this is my last news to take.
# So then, in my last post, I said that The Last Man of Earth was coming and that I was going to have a lot to say about it.<|endoftext|>I have been a reader of this site a long while now and I can not tell you much because I am only looking into how this
# ======== SAMPLE 1 ========
#  Condition. It provides the opportunity for you to play in and join us for a new round of fun!
#
# If you'd prefer to join and try our new mode of play, simply visit our forums and post here or on the Facebook group.
# If you'd like to know more about what we are up to, please visit the wiki, which is available in .pdf format
# We need a good time to play.<|endoftext|>The United Nations High Commissioner for Refugees' (UNHCR) will provide refugee services to the city of Lusaka this week, with UN High Commissioner for Refugees Riyad al-Mudin announced that an operation was to be launched to help the city's refugees and to help it cope with growing demands from migrants.
#
# Muddi al-Bouthi, the High Commissioner for the UN-registered refugee agency in the city, confirmed that the operation to help meet the needs of refugees from neighbouring countries will be launched on August 25.
# The agency will provide more than 50,000 displaced persons, mostly women, with shelters in the city in the event of their forced departure, al-Mudin said in a statement.
# The UNHCR will send 10,000 people through the city to seek alternative lives without the danger of persecution or abuse, al-Mudin added.
# The UNHCR has raised a number of issues related to the issue of the city's refugee population, in particular the number of children it receives.
# Mudin noted that the UNHCR has been "encouraged by the increase in the number of children arriving in the city", pointing out that many of the cases are brought about by migrants who attempt to cross to the region's third-largest city of Lusaka, although it is very close to the Turkish border.
# She also pointed out that the government has been working with UNHCR representatives in Lusaka to reach a consensus for a solution because a number of them were forced to leave the city.
# This is not the case; it's my way; my way is a good and very noble way; and, while you are the cause of me, the cause of yours is a good life; and I'll do well to sit there; I'll do well to sit on one; and then you, and you and me, and I, will sit, I'll rest with nothing, but the one, and the other, and the other, and we'll go on, we'll go on, we'll go on, we'll go on, we'll go on, we'll go on.
#
# I think you are right, you are right.
# I'll stand and stand, when you're gone.
#
# And
# And what is it, you say, you're just a good person.
# I was your daughter's husband, and she's a good wife for me. I'll be a good wife for her too; it's the only thing that really matters.
# We'll come down and you'll come down.
# Well, we'll do and we'll go on; not one thing's left. 'Tis a bad state of affairs.
# For you, you, you'll do well.
# I'd be well. I'd be well, but you've got the wrong idea about children.
#
# 'Tis no good that I should have a daughter, since I am in love with a bad wife: not that she would come and bring me, because of what I have done; but that is the way she should be.
# I've had a good wife to be a good wife, and she'd brought me my thing. What a difference in the affairs of such a
# ======== SAMPLE 1 ========
#
# You don't expect her to be a woman?
#
# She doesn't have a woman's daughter or even a child.
# Is there some secret you haven't learned since she was born?
# She says she's a nurse, and not a nurse,
# but when she's the one you'll need.
#
# How's her doctor? Why, he says, he'd not have any knowledge
# that had been discovered by this doctor and that nurse,
# but I need them, so I have no need of me.
# What's the matter then, Mrs. Wigglesworth, we are both dead. It's done.
#
# How'd you like me to stay? Was there something worse that should be done?
#
# What you want, is, is a boy. That's a boy.
# What, we'd come home, but it's not too late. I have come to hear you speak, and we speak of your uncle and his wife and boy.
#
# How have you met in the state, sir?
# Where, where, how have we talked? Where, sir? How long? How are I?
# Do you like to be here?
# The last thing you asked, sir, is, of my uncle. What's that do- you? What are you doing here?
#
# My uncle says that I'm a stranger, and now I'm all the way here. I'll be in. I'll be.
# My uncle, sir, is the master of this church, which is where the chief is. I'll come here to your father, and he'll be in to see us.
#
# Now I'll pray you
# I'll pray you, sir, what do you say?
#
# I will say nothing as to what I said. I cannot go down from my father's, but I will go from my uncle, I'll go, and I'll come home.
#
# Your father, who has come from a church, you will know he here is not a pastor.
#
# Where did he come?
# He comes from a church!
# Who is that?
#
# What church? I did hear you say I had one. It's a boy, sir. Was there one? I'll take him to see you, and if he is not I'll take him.
#
# Is not that God?
# I hear he does: in the presence of man, but no man.
# Why?
# Well, he's a young man.
# If that be the church, he means it.
# Who's the priest?
# Isn't he the schoolmaster, sir?
# I know the child.
# Who comes home?
# Who comes home?
# What he comes, how I cannot tell.
#
# Who comes home? No, the child, sir.
# What is the child?
# He comes home.
# Where, where?
# He comes home.
# What child? What child? Who the child is?
# Do you not know his name?
# Who, sir, comes home?
#
# Who?
# What child? Where is the child?
#
# Where is the child?
# Where? Where? There is the child.
# Where, where? Where? Where?
# Where, where, where? Where?
# Where, where? Where? What, where? What, what?
# Where? That is the father of the child.
# Where? He comes home.
# Why? I'll have to ask.
# Where, where? Where, where? Where?
#
# Where, where? Let me talk to you, sir. I'll come for him if he comes home too.
# Where, where?
# Where.
# How? Where?
# Where?
# Where?
# Where?
# Where?
# Where?
# What? Where?
# Where, where? How?
# Where? Where?
# Who?
# Where. Why? Where? Why?
# Where?
# How?
# Where?
# Where?
# Where. What?
# Where? It's not there
# I'll come.
# Where?
# Which?
# Where?
# Where?
# Where.
# Where?
# Where?
# Who, sir?
#
# What?
# Where. How? I'll say something
# As I'll say, as I'll say something;
# Why? Why? He's a boy!
#  What's that? God!
# The child, I'll say. Well, why, and I'll speak. God, pray, for the child's sake,
# it's not that God does not make things, but only his own.
#
# My God, why, that's so, that you may not doubt me?
# Why so, for God he will come of his own accord.
#
# Why did I go, sir?
# Who should come?
# I go, and I am at the house;
# I will go, and I is to come to your house
#
# [15 | 113.19] loss=3.53 avg=3.55
# ======== SAMPLE 1 ========
#  'a game for your heart' - to which all the men who had been in the battle were silent.
#
# Then she came up to the king and said with great reverence:--
# And he said: 'My Lord, what are you going to do?
# 'Why, my Lord'
#
# 'Because I am coming to do this,'
# 'Because you say:--
#
# 'I am coming here to tell
# to the king,--
# And I am coming you to do this.'
#
# I'll bear you to my Lord,
# so you may see my purpose,
# for I am coming you
# to say: 'Go along. I would have you go
# to the enemy,
# and come to the castle,--and give you away
# you must go back by the means of the enemy.
#
# 'My Lord!'
# 'Why, why, why!
# Why, why!
# Why, why, why!
# A king
# would have me come; now we will fight,
# when we stand, and be victorious.
# So I will bear you to my word:
# Go there, let them fight,
# for I have a way to make
# you go now.
#
# My lord!'
# 'Why, why, why!
#
#
# I will bear you to my word:
# Go there!
# 'Where we fight, you know,
# the enemy is gone, and
# on the ground I will bear you to my word.'
# Then he called out:
# What the hell!'
#
# Why, why?
#
#
# 'Why, why?'
#
# 'Why?
#
# Why, why, why,
# why!
# I cannot bear to see,
# and will see, and will behold
# these unyielding, unchangeable and
# unwilling foes.
#
#
# And so shall they come; and I will bear you to my word.
#
# I will bear you to my word,
# And bear you back:--
# I will bear you back:
# And you will, I will bear you back.
#
# We will fight, and we will come to the
# battle;' and
# We are the soldiers fighting,
# men-against-men-in-man-war, and
# man against man.
#
# And you will we; 'all men and all the ground.'
#
# Then he went to his king and
# went and heard that the king was coming.
# He heard the king say:
# For he hath done this: for he hast not the ground
# to fight: for he doeth with an axe;
#
# For so he does now.' Then
#
# What is that,
# what's it that you do?'
#
# 'Then,
# I'll follow.'
#
# 'Then,
# '
# 'Then, 'Then,
# '
#
#
# 'Then, '
# 'Now, '
# '
# 'Hath not,
# '
# 'So will we?
#
# 'Then, '
# '
# 'Well, then, 'I did, did we?
# How is it? and how did we,
# do you so?
# If you did, then, by the wisdom of the
# good and the good,
# if you and I should do the matter right'--
# The good, because you have no ground--
# the bad: I do not know
# you:--
# 'No! that thou wilt,
# when thou diest the night, thy enemy hath
# began
# in war on us.
#
# 'Then, thou hast done this: for thou hast not the ground to stand
# but now it is in us: for
# she is we who have done this, and by this,
# that thou art the son of God.
#
# 'Now, thou son of God, and
# God!
# 'That they do now. '
# 'What you did and thou shalt do is here with these
# foes: 'Hath we never seen thee?
#
# 'But not for your fathers, or thy fathers,
# I am here; 'For the father, father of men
# I see thee: 'For your fathers, and your fathers'--
#
# And that you are the father has nothing to do with thee,
# so thou shall not speak of it.
# 'Behold,
# for thy fathers,
# thy fathers, sons and daughters, thy
# men, as it were, and thou shalt not speak of it.
# 'For thy fathers, and his father, the son of this
# father-of-the-age, thee
# I shall not mention 'but thy father, and thou
# thy father, and thou shalt not speak of it,
# but thou shalt speak of thee.
#
#
# 'As it is in thy land: thee comes thy father the father of
# his generation, and thou thy father the father
# of the generation, and thee comes thy father and
#
# ======== SAMPLE 1 ========
#  Angelo!
# A. M.
# What, you! What, we, we were in the midst,
# The first of our people?
#
#
#
#
# WO, we were all in the midst. Look now.
#
# QUEEN OF LAUNANES
#
# I have, I do have one wish of yours,
# I fear not, but you'll think he too great.
#
# QUEEN OF LAUNANES:
#
# Where was this man? What did he wish?
#
# QUEEN OF LAUNANES:
# He took and took out some of our men in his wagon;
# And after you'd done this, you got him?
#
# QUEEN OF LAUNANES:
# What, he had not done.
#
# QUEEN OF LAUNANES:
# No, no. A gentleman of our company had done
# to these our folks, that we were.
# Where was this thing? Here he is.
#
# QUEEN OF LAUNANES:
# I did not take these with you by his side.
#
#
# QUEEN OF LAUNANES:
# When this happened, I think I made some noise,
# For I was not so very glad
# To hear what the chief gentleman of this company had done
# To the good citizens of his company;
# That was no noise. And I did
# Not speak, of an hour of time,
# And did not speak at all.
# And I did not say you hear,
# For I was not that way.
#
# QUEEN OF LAUNANES:
# My, and my own?
#
# QUEEN OF LAUNANES:
# I made none to speak. Not one thing.
#
# QUEEN OF LAUNANES:
# I shall be as quiet as a man.
#
#
# QUEEN OF LAUNANES:
# Nothing of a business, by my father.
#
# QUEEN OF LAUNANES:
# How, by God, he did so much to hear?
#
#
# QUEEN OF LAUNANES:
# As I were in a day' time.
# I was not in that company, 'twere and of that company,
# That, sir William of Oxford, sir John the Prince
# of Surrey,
# And yet, sir Edmund,
# There was none of them to say more.
#
# QUEEN OF LAUNANES:
# Where did you get him, sir?
#
# QUEEN OF LAUNANES:
# I saw him here, here, and
# That he was his father's brother.
#
# QUEEN OF LAUNANES:
# Why, how, how much is he?
#
# QUEEN OF LAUNANES:
# The crown of the crown, sir John,
# You hear him say?
#
# QUEEN OF LAUNANES:
# His Majesty,
# Sir John the Prince's brother,
# There is a crown! and he had a crown
# Here; here he is.
#
# QUEEN OF LAUNANES:
# What, why, he is not such a crown?
#
#
# QUEEN OF LAUNANES:
# That is the crown of our crown;
# And sir John his son the Prince
# His father's brother,
# Of Surrey: sir Edmund.
#
# QUEEN OF LAUNANES:
# Here! here! here! it is there! but
# What is it? the crown of our crown
# No matter, my child, it is mine; no? this is done
# By my father, sir William of Oxford;
# And, sir Edmund, where are you?
#
# QUESTION OF RICHARDSON;
# Sir John, why, I did not see him so
# But there comes about
# What manner of people come and stay in
# They say not, 'tis true,
# 'Sir John, they say that our father is dead to him;
# I tell you what: here is a crown.
#
# QUESTION OF RICHARDSON;
# Why, I will tell you
# Then is my father dead
# He sent him to him, and gave him:
# Now, sir John, what is thy father
# And his blood, and's his ashes?
#
# QUESTION OF RICHARDSON;
# Where is he? what is this? I do not know;
#
# QUESTION OF RICHARDSON:
# That is his son's brother,
# And his father's brother.
#
# QUESTION OF RICHARDSON:
# And here comes his dead.
#
# QUESTION OF RICHARDSON:
# I will tell you:
# No, sir John, you will take
# That crown away.
#
# QUESTION OF RICHARDSON:
# What is so, then?
#
# QUESTION OF RICHARDSON:
# [20 | 145.03] loss=3.47 avg=3.53
# Saving checkpoint/run_1/model-20
# W0215 12:32:47.248793 139957605082944 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Sir, it is not so.
#
# DUKE:
# Hark!
#
# PESSIUS:
# I am content with our Lord of Lordship, and with his subjects; let us take our leave.
#
# DEAR HARDING:
# Thou art the King; my lordship, the king is at your side.
#
# KING:
# How do you think we shall resolve it?
#
# ANUELIO:
# Our Lordship, when I come to speak with thee I shall find you all in peace; and therefore be most content,
# because our hearts are well. But I will tell thee again, and not
# on this day:
# I think I speak well of my Lordship.
#
# PEARLANCE:
# Thou dost swear that thou canst in all
# things, and most good that I can: for thou darest tell
# I must with the king to the king that I dost.
#
# PESSIUS:
# I shall do it to my good sense, and I will make thee
# my friends in the king, and I will make thee a prisoner
# therefore, if I might, to the king.
#
# DUKE:
# Sir, I have my lordship's sword in my hand.
#
# ANUELIO:
# To be honest, what I have told me, and this
# meant of your lordship is not my opinion.
#
# DUKE:
# Ay, that we have not but two knights in
# my hands.
#
# PEARLANCE:
# Why have you told me to be a knight?
#
# KING:
# Ay, for you do have a hand in all; therefore not
# any-one, nor any-one, may hinder me,
# I pray you, for ever.
#
# BASICH:
# Ay, that I had them all but myself,
# when that my master took away.
# I will, for ever, obey them.
#
# PROCEPIO:
# As you see, he did do this, my lord;
# He knew not of our presence; nor did he;
# Nor I nor any, that I did, but his hand.
#
# BERY:
# Ay, for the king and all my subjects
# are content that we have the King's army,
# and not my hands and lordship.
#
# DUKE:
# Nay, that not; yet I trust the king
# does not know; yet not for any
# thing.
# I would not advise them; but their faith do
# affect.
#
# PROCEPIO:
# O, how then, my lord! how then,
# to hear all what hath been told, I
# would not advise.
#
# DUKE:
# Well, your lordship! how then,
# shall I, with a few more men
# as well as our officers?
#
# BERY:
# Sir, I must say that I have a command,
# that if thou wilt not hear what they say,
# that shall be done.
#
# DUKE:
# O, the heavens answer thee; but what
# they say do I, with a few officers
# as well as of my officers; the
# thrifty command of my officers
# shall be done through them to-morrow.
#
# BERY:
#
# PROCEPIO:
# Nay, well, the truth of these things.
#
#
# DEAR HARDING:
# Hark!
#
# BERY:
#
# PROCEPIO:
# This is the matter of our lord, the
# guard of our officers, and of his subjects;
# and the subject, our officers, shall
# not have time to hear: the king will have them
# and his subjects.
#
# DEAR HARDING:
# What was I told you, or had I?
#
# PROCEPIO:
# The very thing was known.
#
# DUKE:
# Good gracious, good gracious, thank the king!
#
# BERY:
# You are much more of a gentleman than I am.
#
# DEAR HARDING:
# God, I must say, no.
#
# PROCEPIO:
# What then, my lord?
#
# BERY:
#
# PROCEPIO:
# I see how you do.
#
# DAVAO:
# A sort of horse, or not so much; be glad.
#
# BERY:
# Ay, that is my master.
#
# BADIO:
# Ay, the king's horse, not well;
# but in all respects the rider is
# well.
#
# DAVAO:
# Ay, how
#
# ======== SAMPLE 1 ========
# .The people, who were ready to offer their support for the present, were well disposed, and their voices loud again, and their words gentle, and their language full, as usual, as we saw them, when we were gone down. So we returned again, and there met our king.
#
# ARLING:
# We were ready for war and peace; but we were not so ready.
#
# KING RICHARD II:
# No further battles; no more fightings; no more of arms, arms and arms, to meet your foes; for my king shall not rest till I have all the army:
#
# Lords of England:
#
# Edward IV: I'll go to her house; let her have no other
# Then, or if thou wilt, thou shalt not see her.
#
# The Duke of York:
# Hie, a little maid will have a son with thee;
# What love's there for the maid?
#
# Edward IV: Here she comes.
#
# Lords of England:
#
# Edward IV: Didst thou hear my lord's words of my father,
# That when he lived, his sister dote upon
# His bosom his love and his maid's love?
#
# Edward IV: Was he born with the daughter
#
# ======== SAMPLE 1 ========
#
#
# Nurse, your life is like fire; but your hair and eyes light that on mine face they bear
# The golden age of your grace, and the great world
# Where your suns, you will have many gods with arms.
#
# SIR:
#
# Brother; why, it's very strange!
#
# FORT:
#
# Aunt Daphne, we have good news:
# But your sister's mother may not be safe,
# If she be there any more alive.
#
# Nurse:
# She must stay out the country.
#
# SIR:
# Come, let us down!
#
# FORT:
# I'll fetch her to my chamber.
#
# Daphne:
#
# My brother's grave-lips, uncle, your sister's death:
# My sorrow is like death's cold breath,
# Which makes you mad, and it's like death's thunder.
#
# Nurse:
# Why, uncle, what else
# Thou shalt do?
#
# SIR:
# I have no way.
#
# FORT:
#
# How: what else is my brother to do?
#
# Nurse:
# He is to go back home to his father's grave,
# And take up a fresh grave-mould.
#
# SIR:
# Amen!
#
# FORT:
# You shall not go home to my father's grave.
# But you are uncle; to the grave-mould,
# To the fresh grave-mould, and thence to all things,
# Of things of your kindred--and to the fresco,
# Of all your kindred's friends, and all good spirits,
# As you will, with an eye for the old grave.
#
# SIR:
# Well, uncle, what do you think?
#
# FORT:
# My sister's grave in my hand.
#
# Nurse:
# Well, uncle, what?
#
# SIR:
# A grave in hand, and a fresh grave-mould,
# As I have made a fresh grave-mould:
# And let me go home again, to the grave,
# To look on the fresco as I saw it when I left
# My father's grave-lips in his hand, with the old
# Cabin, and his friends, like myself,
# And take up the fresh grave-mould and bury the old
# Cabin, to my father's grave and to uncle's grave
# With my friends, who have been brought up,
# With their hearts filled with hopes and joy;
# With a sweet and merry heart, and a love-song to
# Be merry.
#
# SIR:
# Here it is: to the fresh-cabin,
# To the fresh grave-mould; on my knees,
# And with thy help I pray thee!
#
# FORT:
# Hark; I will put these things on the grave,
# And then make a fresh grave-mould,
# And I will take up the fresh grave-mould,
# And bury the fresh-cabin, and lay my sister's head
# Out of the grave, and in the new grave-mould.
#
# SIR:
# My brother will bring the fresh grave-mould out again;
# And I'll take up the fresh grave-mould and the fresh grave ;
# And I will put it on the grave; and in the grave,
# And bury it and bring that new grave-mould
# Back to me.
#
# SIR:
# O heaven! bless God! what a shame! What a shame! thou hast done that!
# Why hast thou done it? let's make it so.
#
# Nurse:
# How? and when, brother! let's do it, and let's go home.
#
# SIR:
# Aye, uncle, go home and to your brother's graves;
# And I shall make a fresh grave-mould for you.
#
# FORT:
# Go home and I'll take up the fresh grave-mould!
# My kinsman to the grave, I have done it.
#
# Nurse:
# And it shall be a fresh grave-mould.
#
# SIR:
# Go, uncle, home to your grave-mould.
#
# FORT:
#
# Go home; and I shall make a fresh grave for them.
#
# Nurse:
# Your brother's grave-mould, my sister's corpse,
# I would like it to come and prove your grace; and therefore,
# I can commend him to you.
#
# BROUGHTON:
# Hensley, I have heard you give him praise
#
# [45 | 337.85] loss=3.20 avg=3.44
# ======== SAMPLE 1 ========
# ru.com
#
# LAST, O, I'll go, the fair Lady, and all her noble friends, and all the noble ladies;
# And if your ladies desire, I will go; and
# They can talk with us and make no agreement with the
# woman.
#
# KATHARINA: I'll go with you a day.
#
# KATHARINA: I am not bound, sir;
# I am the lady, and I am the good lady, and I am
# the good lady, and I would like you a seat for me on
# the seat, if you might, in the same chamber,
# with the lady.
#
# PETRUCHIO: You are right, the ladies have been to my
# be-
#
# KATHARINA: Yes, and they have been.
#
# PETRUCHIO: Come hither, gentlemen. I want all three.
#
# LOMBOLY: Come, gentlemen; you will do my business.
#
# BUCKINGHOUSE: The ladies will follow you.
#
# KATHARINA: My lady, I have seen you in the stately fashion, and
# she is now in the well-fitted suit; so have the gentlemen, and
# she will stand well with you. I did say, this was the fashion,
# and I think it is a fine and fair one too;
# but I would do your business well and do as I please.
#
# KATHARINA:
#
# PETRUCHIO: Let's go, gentlemen, and go and hear more,
# because we are in a time to strike the notes,
# and not for any business.
#
# KATHARINA:
#
# PETRUCHIO:
#
# LOMBOLY:
#
# BUCKINGHOUSE:
# What is it, to hear a suit, as we may,
# and have an exchange, with another, and so be done?
#
# GLOUCESTER:
#
# LOMBOLY:
#
# PETRUCHIO:
# Sir, sir, sir; I have seen you in all manner, in you suits and
# your suities, so have your ladies. I have seen you in the way,
# and with all the gentlemen you have, so have your
# hands. I have said, as I do, that it is not the suit, but the
# suities, and both hands I have, that make me suit.
#
# GLOUCESTER:
#
# KATHARINA:
# Yes, sir; that is a well-fitted suit, and a suit, as is
# fit for a gentleman's suit.
# The men are in the stately business, and the ladies
# have no more than their hands ready to do.
#
# KATHARINA:
#
# GLOUCESTER:
# We are in the suit of gentlemen, and we will suit.
#
# KATHARINA:
# The ladies have their marks; well-fitted suits do need some people, and I do not
# like the ladies. There is a common man of good will here, sir;
# and in the suit I need no more than I have in my suit.
#
# GLOUCESTER:
# This suit is a well-fitting suit, and suities suit.
#
# KATHARINA:
# What suit?
#
# PETRUCHIO:
#
# GLOUCESTER:
# The men, with some ladies I have, will suit my suit.
#
# KATHARINA:
# Well, he is gone.
#
# PETRUCHIO:
# Sir, what, where was he?
#
# KATHARINA:
#
# PETRUCHIO:
# I must say that the women are in the stately business
# now.
#
# KATHARINA:
#
# PETRUCHIO:
# Go out, let's go.
#
# GLOUCESTER:
# Go out; you'll see where he is; he is gone.
#
# KATHARINA:
#
# PETRUCHIO:
# Ay, in stately business, and we shall do him no harm.
#
# GLOUCESTER:
# Well, for the ladies, it is like being in a fit suit,
# that a suit is fit for a gentleman.
#
# KATHARINA:
# What is the suit?
#
# GLOUCESTER:
# They have a pair of shoes for the ladies.
#
# KATHARINA:
# Is it a suit?
#
# GLOUCESTER:
# No.
#
# KATHARINA:
# Or a suit of shoes for the ladies.
#
# GLOUCESTER:
# A two-edged suit, like a suit, a well-fitted suit; but the ladies are
# weary.
#
# KATHARINA:
# Well,
#
# ======== SAMPLE 1 ========
#  thank,
# To give one of their eyes a new look:
# And one of their eyes to be seen
# Shal be the first of this love.
# Now I'll bear you back, and, at the door
# Of this chamber, I'll give unto you a new
# lady a smile;
# With gentle gentle kisses, and, in my bed,
# And in your bed, a new kiss.
#
# MOUTH:
# This sweet girl, I say, hath the
# best of our hearts in this room.
#
# O:
# I can't thank you.
# So kiss with this good girl
# And in such loving loving love you
# Have a love of mine: love a man so; love a woman so
# A man so; love a man so: love a woman so, too.
#
# QUEEN:
# You have the best of yours, my lord;
# You have the best hearts of mine!
#
# O:
#
# QUEEN:
# Holds me well in you, and he best.
#
# CLIFF:
# You cannot tell who is the worst in this room
# Or who is more than the worst.
#
# QUEEN:
# That, my lord, is so; he, it is as the worst;
# He must be no better than the good.
#
# CLIFF:
# I know not how, my lord. I need not to hear.
#
# QUEEN:
# O!
#
# CLIFF:
# O!
#
# QUEEN:
# Then, my lord!
#
# CLIFF:
# O, O!
#
# KING RICHARD II:
# I pray thee, what, the world; a prince should
# Make such a world without me, and I with the
# other!
#
# QUEEN:
# How, what, what, thou art so, and thus I must
# Thou love in thyself!
#
# QUEEN:
# But if thou do make so, I think he shall
# Make so much of thee.
#
# KING RICHARD II:
# I see with these words thou hast but a
# great mind: it is not for thee to think, my lord:
# Thou hast but a mind to love! Thou art such a mind!
#
# QUEENS:
#
# QUEENS:
# A true dream, my lord, but one of a
# fog; where were thou in it? Where have the
# duperly-shoved eyes? Thou dost
# be in there.
#
# O:
# KING RICHARD II:
# O God!
#
# QUEENS:
# O, good dost thou, if thou art not so
# so, let him, let him, let him!
#
# KING RICHARD II:
# O, my lord, good dost thou, if thou art not so
# I do not love; but if thou art so, there is
# nothing else to take thy soul.
#
# QUEENS:
# My lord, thou art in that prison cell! Here am I;
# here am I this good night, which thou wilt
# take the night to be the good night in me!
#
# QUEENS:
# Is not so, this night that thou gavest so much, being so
# strong. The heavens are full, O God! what dost thou
# swear, for I am a good night?
#
# QUEENS:
# Why, so thou shouldst have
# stayed night under the bed, for thyself I
# had slept that night; for it was a
# night, and thou hast not slept in it.
#
# QUEENS:
# So that thou hast sleep'd this morning, thou dost
# do me a welcome night.
#
# KING RICHARD II:
# O, I thank thee.
#
# QUEENS:
# What?
#
# KING RICHARD II:
#
# QUEENS:
# How! what?
#
# KING RICHARD II:
# Thou hast not so.
#
# QUEENS:
# This is the day; it is the day of my queen
# Nymphs.
#
# KING RICHARD II:
# Now I have not slept before: where is thou, O King Richard?
#
#
# QUEENS:
# Where, then?
#
# KING RICHARD II:
# You have slept since you were king.
#
# QUEENS:
# No, no: yet I am king: I may
# go to him where my queen was born now.
#
# KING RICHARD II:
# I was once royal king.
#
# QUEENS:
# Hear, then, when thou art king you have been in London too
# long to take me prisoner.
#
# KING RICHARD II:
# Hear how that was a fearful night! what had
# the court do?
#
# QUEENS
# [50 | 369.63] loss=3.31 avg=3.43
# Saving checkpoint/run_1/model-50

# %% [markdown]
# ## Generate Text From The Trained Model
#
# After you've trained the model or loaded a retrained model from checkpoint, you can now generate text. `generate` generates a single text from the loaded model.

# %%
gpt2.generate(sess, run_name='run_1')
# Out:
# Would this be the first time you have seen this
# When you were in a battle with the enemy?
#
# KING RICHARD II:
# If this were the first time you had seen it,
# I would tell you what makes this thing so.
#
# CHAP. VI:
# This is my lord, your lord.
#
# RICHARD II:
# I do, my lord.
#
# CHAP. VI:
# And thou undid all that thou hast done.
#
# RICHARD II:
# This is a part of some duty of mine:
# This is made of some duty of mine.
#
# CHAP. VI:
# My lord, this is an unhappy part of thy duty:
# No further part of thy duty is my part.
#
# RICHARD II:
# You may not be so much old as I am old.
#
# CHAP. VI:
# What, then, shall I see thee at the match?
#
# RICHARD II:
# I do not think so big a match
# Of myself and of my eyes.
#
# CHAP. VI:
# How, then, do you see the match?
#
# RICHARD II:
# I know not what.
#
# CHAP. VI:
# What, then, endeth this match?
#
# RICHARD II:
# Tears were shed for good friends, and we were slain
# Without a word.
#
# CHAP. VI:
# You, my lord, have three hundred thousand men.
#
# RICHARD II:
# I am not such a thing.
#
# CHAP. VI:
# Why, then, is this so?
#
# RICHARD II:
# I doubt not.
#
# CHAP. VI:
#
# These are my friends:
# My princes, my friends, my friends;
# Oh, your lords, my friends, my friends!
#
# RICHARD II:
# That were not so.
#
# CHAP. VI:
# Now, let me die;
# As I had done, in thy service,
# Not to serve thee like thy brother was.
#
# RICHARD II:
# What, then, did thou die?
#
# COMINIUS:
# He did die.
#
# CHAP. VI:
# I do, my lord.
#
# RICHARD II:
#
# What, then, did thou die?
#
# COMINIUS:
# He did die.
#
# CHAP. VI:
# What, then, were thou that hast died?
#
# COMINIUS:
# He did die.
#
# DUCHESS ELIZABETH:
# What, then, did thou die?
#
# COMINIUS:
# This we do not know.
#
# DUCHESS ELIZABETH:
# What, then, have thou come to die?
#
# COMINIUS:
# I did come to die; but thou hast not come
# To have it.
#
# DUCHESS ELIZABETH:
# What, then, have thou come to die?
#
# COMINIUS:
# I would not have it, but thou hast come.
#
# DUCHESS ELIZABETH:
# What, then, have thou come to die?
#
# COMINIUS:
# I would not, but thou hast not come.
#
# RICHARD:
# And it is not a lie.
#
# COMINIUS:
# As thou hast not come, thou hast not come.
#
# RICHARD:
# What, then, have thou come to die?
#
# COMINIUS:
# I have not come to die.
#
# RICHARD:
# Is it not a lie, then, that I would not have it?
#
# COMINIUS:
# Have you not been dead?
#
# RICHARD:
# No, sir.
#
# COMINIUS:
# You are dead, sir.
#
# RICHARD:
# No, sir.
#
# COMINIUS:
# I should have it.
#
# RICHARD:
# No, sir.
#
# COMINIUS:
# I should have it.
#
# DUCHESS ELIZABETH:
# What, then, have thou come to die?
#
# COMINIUS:
# I would not have it, sir.
#
# DUCHESS ELIZABETH:
# Who, sir, did you die?
#
# COMINIUS:
# I would not have it.
#
# DUCHESS ELIZABETH:
# I would not have it.
#
# DUCHESS ELIZABETH:
# Why, then, didst thou die?
#
# COMINIUS:
# I would not have it.
#
# DUCHESS ELIZABETH:
# I would not have it.
